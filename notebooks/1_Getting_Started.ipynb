# %%
# %load_ext autoreload
# %autoreload 2

# %%
from metricx import Metric, Task

task = Task(
    name="hello-world",
    metrics=[
        Metric(name="score", is_higher_better=True),
        Metric(name="fit-time", is_higher_better=False),
    ],
)
task.report("model-1", {"score": 1.0, "fit-time": 0.1})
task.report("model-2", {"score": 0.0, "fit-time": 0.4})
task.report("model-2", {"score": 0.1, "fit-time": 0.5})

task.to_figure();
